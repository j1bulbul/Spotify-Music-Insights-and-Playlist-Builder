# %% [markdown]
# Objective:
#
# The main goal of this notebook is to interface with the Spotify API, retrieve our saved tracks (includes album info), top tracks, and top artists and preprocess the data for subsequent analysis. This initial step is crucial to ensure data quality and set the foundation for our data visualisation and modeling stages.

# %%
# !pip install spotipy pandas

import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
# Out:
# Requirement already satisfied: spotipy in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (2.23.0)
# Requirement already satisfied: pandas in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: redis>=3.5.3 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from spotipy) (4.6.0)
# Requirement already satisfied: requests>=2.25.0 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from spotipy) (2.29.0)
# Requirement already satisfied: six>=1.15.0 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from spotipy) (1.26.16)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jacobbulbul/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2023.5.7)

# %% [markdown]
# Now that our libraries are in place, we'll proceed to authenticate with the Spotify API using the credentials from our developer dashboard and ther spotipy library to make things easier (doing this slightly more manually as I wanted to be explicit with my work). Remember to always keep your client_id and client_secret confidential.

# %% [markdown]
# ## Note: For the below two cells the outputs have been removed so as not to leak sensitive information. You must include your own Client_ID,  Client_secret, and redirect URI for OAuth2 for the Spotify API after creating your Spotify developer account (and specifying your redirect URI) if you wish to do this yourself.
#
# # Running the code in the below two cells as is will result in an error.
#
# # Some info:
# - The output of the 1st cell will provide an auth_url link which you must use (only once and you don't need to run it again) to authorize use of your/a user's account.
#
# - The output of the 2nd cell will print your access and refresh tokens for your reference, but the code itself will store them and utilise them appropritately to make API calls via the Python Spotipy library.
#
# ## Alternatively, if you're here just to browse my work, the other cells will show you the resulting data pulled from my Spotify account (the final dataframes after cleaning are saved as CSV files at the end of this notebook and are also provided in the Github repo).

# %%
auth_manager = SpotifyOAuth(client_id="YOUR_CLIENT_ID_HERE",
                            client_secret="YOUR_CLIENT_SECRET_HERE",
                            redirect_uri="YOUR_REDIRECT_URI_HERE",
                            scope="user-library-read user-top-read")

auth_url = auth_manager.get_authorize_url()
print(auth_url)

# %%
import urllib.parse

# Replace this with the auth URL you generated in the preceeding cell
redirected_url = "YOUR_AUTH_URL_HERE"

# Extract the code from the URL
parsed_url = urllib.parse.urlparse(redirected_url)
code = urllib.parse.parse_qs(parsed_url.query)["code"][0]

# Get the access token using the code
token_info = auth_manager.get_access_token(code)
sp = spotipy.Spotify(auth=token_info['access_token'])
print(token_info)

# %% [markdown]
# With our Spotify API connection established for a given authenticated user, let's now fetch saved tracks.
#
# From now on, the data you see will be from my Spotify account.
#
# This will give us a first glance at the songs that the user manually chooses to save on Spotify.  We'll then convert this data into a Pandas DataFrame for easy manipulation and cleaning.

# %%
from IPython.display import display
import pandas as pd

# Function to fetch a user's liked/saved tracks from Spotify.
def fetch_saved_tracks(sp):
    offset = 0  # Offset for paginated results.
    tracks = []  # List to hold all the fetched tracks.
    
    # Continuously fetch tracks in batches of 50 until all tracks are fetched.
    while True:
        # Fetching the next set of tracks.
        response = sp.current_user_saved_tracks(limit=50, offset=offset)
        
        # Extending our list with the fetched tracks.
        tracks.extend(response['items'])
        
        # If less than 50 tracks are returned, we've fetched all the tracks.
        if len(response['items']) < 50:
            break
            
        # Increase the offset by 50 to fetch the next set of tracks.
        offset += 50
        
    return tracks

# Calling the function to fetch saved tracks.
saved_tracks = fetch_saved_tracks(sp)

# Constructing a DataFrame from the fetched tracks.
df_tracks = pd.DataFrame([(track['track']['id'],
                           track['track']['name'],
                           track['track']['artists'][0]['name'],
                           track['track']['album']['name'],
                           track['track']['album']['release_date'],
                           track['track']['duration_ms'],
                           track['added_at'])
                          for track in saved_tracks],
                         columns=['id', 'name', 'artist', 'album', 'release_date', 'duration_ms', 'added_at'])

# Making a copy of the DataFrame for further use.
df_tracks_copy = df_tracks.copy()

# Displaying the first few rows of the DataFrame.
display(df_tracks.head())
# Displaying info about the DataFrame.
df_tracks.info()
# Out:
#                        id                             name     artist  \
# 0  2UOopL3Y405ruJyMzJcdWD                     Khserna Baad  Maya Diab
# 1  0WVTQp3SOCuMr08jh1jweV           Bring It On Home to Me  Sam Cooke
# 2  1XPj5quoeV5Gd0paSUDpvm               You Send Me - Mono  Sam Cooke
# 3  2G0GextMwZJLkNxcSZ7ZJ3  (What A) Wonderful World - Mono  Sam Cooke
# 4  1HkOPLwAJH3kE8UnqgxF4s                      Skinny Love   Bon Iver
#
#                               album release_date  duration_ms  \
# 0                      Khserna Baad   2019-06-03       187561
# 1         The Man Who Invented Soul   2000-09-26       162533
# 2                         Sam Cooke   1958-02-01       165733
# 3  The Wonderful World Of Sam Cooke      1960-02       128786
# 4             For Emma, Forever Ago   2008-05-12       238532
#
#                added_at
# 0  2023-08-03T19:11:51Z
# 1  2023-08-01T16:48:21Z
# 2  2023-07-23T14:55:49Z
# 3  2023-07-20T01:18:55Z
# 4  2023-07-20T00:55:48Z
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            791 non-null    object
#  1   name          791 non-null    object
#  2   artist        791 non-null    object
#  3   album         791 non-null    object
#  4   release_date  791 non-null    object
#  5   duration_ms   791 non-null    int64
#  6   added_at      791 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 43.4+ KB

# %% [markdown]
# Now, well utilise the info obtained from Spotify's search artist endpoint to provide the genre for all our saved tracks and merge it into our saved tracks dataframe for genre-specific analysis/visualisations

# %%
#add in genre info for each saved track
# Get a list of all unique artists in your saved tracks
unique_artists_saved = df_tracks['artist'].unique()

# Initialize a list to store individual artist dataframes
artist_frames = []

# Loop through each unique artist
for artist in unique_artists:

    # Use the Spotify search API to get details about the artist
    # 'q=' specifies the search query, in this case the artist's name
    # 'type=' specifies the type of search, in this case we're searching for an artist
    results = sp.search(q='artist:' + artist, type='artist')

    # Check if any artist details were returned
    if results['artists']['items']:

        # Get the first (and most relevant) artist's details from the returned items
        artist_info = results['artists']['items'][0]

        # Create a dataframe from the artist's details and add it to our list
        # We're only interested in the artist's name and their genres in this case
        artist_frames.append(pd.DataFrame([{
            'name': artist_info['name'],
            'genres': artist_info['genres'],
        }]))

# Combine all the individual artist dataframes into one big dataframe
df_artists = pd.concat(artist_frames, ignore_index=True)

# Merge the saved tracks dataframe with the artist details dataframe
# 'left_on=' specifies the column in the left dataframe to merge on, in this case the artist's name
# 'right_on=' specifies the column in the right dataframe to merge on, in this case also the artist's name
# 'how=' specifies the type of merge, in this case a left merge which keeps all rows from the left dataframe and only matching rows from the right dataframe
df_saved_tracks_genre = df_tracks.merge(df_artists, left_on='artist', right_on='name', how='left')
#save a copy to refer to in case issues arise when cleaning the data e.g. dropping columns/rows
df_saved_tracks_genre_copy=df_saved_tracks_genre.copy()
display(df_saved_tracks_genre.head())
# Out:
#                        id                           name_x     artist  \
# 0  2UOopL3Y405ruJyMzJcdWD                     Khserna Baad  Maya Diab
# 1  0WVTQp3SOCuMr08jh1jweV           Bring It On Home to Me  Sam Cooke
# 2  1XPj5quoeV5Gd0paSUDpvm               You Send Me - Mono  Sam Cooke
# 3  2G0GextMwZJLkNxcSZ7ZJ3  (What A) Wonderful World - Mono  Sam Cooke
# 4  1HkOPLwAJH3kE8UnqgxF4s                      Skinny Love   Bon Iver
#
#                               album release_date  duration_ms  \
# 0                      Khserna Baad   2019-06-03       187561
# 1         The Man Who Invented Soul   2000-09-26       162533
# 2                         Sam Cooke   1958-02-01       165733
# 3  The Wonderful World Of Sam Cooke      1960-02       128786
# 4             For Emma, Forever Ago   2008-05-12       238532
#
#                added_at     name_y  \
# 0  2023-08-03T19:11:51Z  Maya Diab
# 1  2023-08-01T16:48:21Z  Sam Cooke
# 2  2023-07-23T14:55:49Z  Sam Cooke
# 3  2023-07-20T01:18:55Z  Sam Cooke
# 4  2023-07-20T00:55:48Z   Bon Iver
#
#                                               genres
# 0                           [arab pop, lebanese pop]
# 1                   [classic soul, soul, vocal jazz]
# 2                   [classic soul, soul, vocal jazz]
# 3                   [classic soul, soul, vocal jazz]
# 4  [chamber pop, eau claire indie, indie folk, me...

# %% [markdown]
# Now, lets further enrich our saved tracks by utilising Spotify's audio features endpoint to obtain detailed audio feature information for each saved track

# %%
#define our fetch_audio_features function and obtain detailed audio features for all saved tracks in batches of 50 (to not violate the API request limit)
def fetch_audio_features(sp, track_ids):
    audio_features = []
    for i in range(0, len(track_ids), 50):
        audio_features += sp.audio_features(track_ids[i:i+50])
    return audio_features
# Fetch the audio features for all tracks
audio_features = fetch_audio_features(sp, df_saved_tracks_genre['id'].tolist())
# Create a dataframe from the audio features
df_audio_features = pd.DataFrame.from_records(audio_features)
# Merge the saved tracks+genre dataframe with the audio features dataframe for full info for my saved tracks
df_saved_tracks_with_audio_features = pd.merge(df_saved_tracks_genre, df_audio_features, how='inner', left_on='id', right_on='id')
df_saved_tracks_with_audio_features_copy=df_saved_tracks_with_audio_features.copy()
display(df_saved_tracks_with_audio_features.head())
# Out:
#                        id                           name_x     artist  \
# 0  2UOopL3Y405ruJyMzJcdWD                     Khserna Baad  Maya Diab
# 1  0WVTQp3SOCuMr08jh1jweV           Bring It On Home to Me  Sam Cooke
# 2  1XPj5quoeV5Gd0paSUDpvm               You Send Me - Mono  Sam Cooke
# 3  2G0GextMwZJLkNxcSZ7ZJ3  (What A) Wonderful World - Mono  Sam Cooke
# 4  1HkOPLwAJH3kE8UnqgxF4s                      Skinny Love   Bon Iver
#
#                               album release_date  duration_ms_x  \
# 0                      Khserna Baad   2019-06-03         187561
# 1         The Man Who Invented Soul   2000-09-26         162533
# 2                         Sam Cooke   1958-02-01         165733
# 3  The Wonderful World Of Sam Cooke   1960-02-01         128786
# 4             For Emma, Forever Ago   2008-05-12         238532
#
#                    added_at  \
# 0 2023-08-03 19:11:51+00:00
# 1 2023-08-01 16:48:21+00:00
# 2 2023-07-23 14:55:49+00:00
# 3 2023-07-20 01:18:55+00:00
# 4 2023-07-20 00:55:48+00:00
#
#                                               genres  danceability  energy  \
# 0                           [arab pop, lebanese pop]         0.689   0.605
# 1                   [classic soul, soul, vocal jazz]         0.523   0.402
# 2                   [classic soul, soul, vocal jazz]         0.572   0.365
# 3                   [classic soul, soul, vocal jazz]         0.686   0.672
# 4  [chamber pop, eau claire indie, indie folk, me...         0.592   0.256
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    7    -7.917     0       0.0776         0.127          0.000000    0.0827
# 1    0    -8.233     1       0.0305         0.778          0.000000    0.4320
# 2    4    -7.583     0       0.0276         0.880          0.000000    0.1250
# 3   11    -5.523     1       0.0323         0.700          0.000000    0.1350
# 4    4   -14.031     0       0.0449         0.842          0.000002    0.0880
#
#    valence    tempo            type                                   uri  \
# 0    0.146   87.017  audio_features  spotify:track:2UOopL3Y405ruJyMzJcdWD
# 1    0.675   70.863  audio_features  spotify:track:0WVTQp3SOCuMr08jh1jweV
# 2    0.410   96.022  audio_features  spotify:track:1XPj5quoeV5Gd0paSUDpvm
# 3    0.857  128.550  audio_features  spotify:track:2G0GextMwZJLkNxcSZ7ZJ3
# 4    0.103   76.358  audio_features  spotify:track:1HkOPLwAJH3kE8UnqgxF4s
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2UOopL3Y405r...
# 1  https://api.spotify.com/v1/tracks/0WVTQp3SOCuM...
# 2  https://api.spotify.com/v1/tracks/1XPj5quoeV5G...
# 3  https://api.spotify.com/v1/tracks/2G0GextMwZJL...
# 4  https://api.spotify.com/v1/tracks/1HkOPLwAJH3k...
#
#                                         analysis_url  duration_ms_y  \
# 0  https://api.spotify.com/v1/audio-analysis/2UOo...         187562
# 1  https://api.spotify.com/v1/audio-analysis/0WVT...         162533
# 2  https://api.spotify.com/v1/audio-analysis/1XPj...         165733
# 3  https://api.spotify.com/v1/audio-analysis/2G0G...         128787
# 4  https://api.spotify.com/v1/audio-analysis/1HkO...         238533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# Now, we'll retrieve a user's top artists and tracks via the top_artists and top_tracks endpoints over short, medium, and long term time ranges (ranges defined on the API documentation). This data can be insightful to understand personal music preferences over different timeframes and curate playtlists for different moods/activities effectively.

# %%
def fetch_top_artists_tracks(sp, type='tracks', time_range='short_term', limit=50):
    """
    Fetch top artists or tracks for a user.
    
    Parameters:
        sp : spotipy client
        type : 'artists' or 'tracks'
        time_range : 'short_term', 'medium_term', or 'long_term'
        limit : Number of results to fetch (maximum 50)
        
    Returns:
        List of results
    """
    if type == 'tracks':
        return sp.current_user_top_tracks(time_range=time_range, limit=limit)['items']
    elif type == 'artists':
        return sp.current_user_top_artists(time_range=time_range, limit=limit)['items']

# Fetching top artists and tracks for all time ranges
time_ranges = ['short_term', 'medium_term', 'long_term']
top_artists = {tr: fetch_top_artists_tracks(sp, 'artists', tr) for tr in time_ranges}
top_tracks = {tr: fetch_top_artists_tracks(sp, 'tracks', tr) for tr in time_ranges}

# %% [markdown]
# Top Artists DataFrame (df_top_artists):
#
# The df_top_artists DataFrame contains data about your top artists from Spotify, categorized by timeframes (short term, medium term, and long term). The columns in this DataFrame are:
#
# id: The unique identifier for the artist on Spotify.
# name: The name of the artist.
# genres: Genres associated with the artist, concatenated as a comma-separated string.
# followers_count: The number of followers the artist has on Spotify.
# popularity: A measure of the popularity of the artist on Spotify, ranging from 0 to 100.
# time_range: The time frame for which the artist is considered "top" (can be "short_term", "medium_term", or "long_term").
# Differences from the Saved Tracks DataFrame:
#
# This DataFrame focuses on artists rather than individual tracks.
# It contains metrics like genres, followers count, and popularity specific to artists.
# The artists in this DataFrame are based on your listening patterns and are ranked as top artists for the specified time frame, whereas the Saved Tracks DataFrame contains tracks you've explicitly saved.

# %%
# Convert top artists data to DataFrame
artist_frames = []

for tr in time_ranges:
    df_artist = pd.DataFrame([(artist['id'],
                               artist['name'],
                               ', '.join(artist['genres']),
                               artist['followers']['total'],
                               artist['popularity'])
                              for artist in top_artists[tr]],
                             columns=['id', 'name', 'genres', 'followers_count', 'popularity'])
    df_artist['time_range'] = tr  # adding a column to specify the time range
    artist_frames.append(df_artist)

df_top_artists = pd.concat(artist_frames, ignore_index=True)
#create a copy of the original version we can refer to just in case after data cleaning/manipulation
df_top_artists_copy = df_top_artists.copy()
display(df_top_artists.head())
# Out:
#                        id           name                               genres  \
# 0  04N4sGkSTSxjVfbiItLvTj    Ziad Bourji               arab pop, lebanese pop
# 1  5K4W6rqBFWDnAN6FQUkS6x     Kanye West            chicago rap, hip hop, rap
# 2  2h93pZq0e7k5yf4dywlkpM    Frank Ocean             lgbtq+ hip hop, neo soul
# 3  09A6IffSw0t8L8sfuOCVws    Wael Kfoury  arab pop, belly dance, lebanese pop
# 4  5DPb3SKW8QZFwkRlmt7Gvo  Joseph Attieh        arab pop, dabke, lebanese pop
#
#    followers_count  popularity  time_range
# 0                0          43  short_term
# 1                0          88  short_term
# 2                0          81  short_term
# 3                0          52  short_term
# 4                0          40  short_term

# %% [markdown]
# Top Tracks DataFrame (df_top_tracks):
#
# The df_top_tracks DataFrame provides information on your top tracks on Spotify, split by the same timeframes. The columns are:
#
# id: The unique identifier for the track on Spotify.
# name: The title of the track.
# album: The album to which the track belongs.
# artist: The primary artist of the track.
# duration_ms: The duration of the track in milliseconds.
# popularity: A measure of the popularity of the track on Spotify, ranging from 0 to 100.
# time_range: The timeframe for which the track is deemed "top" (can be "short_term", "medium_term", or "long_term").
# Differences from the Saved Tracks DataFrame:
#
# While both DataFrames contain track-related information, the Top Tracks DataFrame specifically ranks tracks based on your listening habits within a certain timeframe.
# The Saved Tracks DataFrame contains tracks you've chosen to save, regardless of how often you've listened to them.
# The Saved Tracks DataFrame has an "added_at" column indicating when the track was saved, which isn't present in the Top Tracks DataFrame.

# %%
# Convert top tracks data to DataFrame
track_frames = []
for tr in time_ranges:
    df_track = pd.DataFrame([(track['id'],
                              track['name'],
                              track['album']['name'],
                              track['artists'][0]['name'],  # taking only the primary artist for simplicity
                              track['duration_ms'],
                              track['popularity'])
                             for track in top_tracks[tr]],
                            columns=['id', 'name', 'album', 'artist', 'duration_ms', 'popularity'])
    df_track['time_range'] = tr  # adding a column to specify the time range
    track_frames.append(df_track)
    
df_top_tracks = pd.concat(track_frames, ignore_index=True)
#create a copy of the original version we can refer to just in case after data cleaning/manipulation
df_top_tracks_copy = df_top_tracks.copy()
display(df_top_tracks.head())
# Out:
#                        id             name                  album  \
# 0  1HkOPLwAJH3kE8UnqgxF4s      Skinny Love  For Emma, Forever Ago
# 1  5DBmXF7QO43Cuy9yqva116  Family Business    The College Dropout
# 2  4vHNeBWDQpVCmGbaccrRzi       Goodie Bag             Goodie Bag
# 3  694vvR5o19xHPhhJ5QdLN7          NO HALO                 GINGER
# 4  093CMFUwvPyFIsjBsVfBPO  El Hob El Kebir        El Hob El Kebir
#
#          artist  duration_ms  popularity  time_range
# 0      Bon Iver       238532          69  short_term
# 1    Kanye West       278893          67  short_term
# 2   Still Woozy       146390          78  short_term
# 3  BROCKHAMPTON       259746          59  short_term
# 4  Ragheb Alama       315640          50  short_term

# %% [markdown]
# Let us now incorporate genre information for our top tracks in a similar fashion to how we incorporated it into our saved tracks

# %%
#we now add genre column to top tracks as we did for saved tracks

# Get a list of all unique artists in your top tracks
unique_artists = df_top_tracks['artist'].unique()

# Initialize a list to store individual artist dataframes
artist_frames = []

# Loop through each unique artist
for artist in unique_artists:

    # Use the Spotify search API to get details about the artist
    results = sp.search(q='artist:' + artist, type='artist')

    # Check if any artist details were returned
    if results['artists']['items']:

        # Get the first (and most relevant) artist's details from the returned items
        artist_info = results['artists']['items'][0]

        # Create a dataframe from the artist's details and add it to our list
        artist_frames.append(pd.DataFrame([{
            'name': artist_info['name'],
            'genres': artist_info['genres'],
        }]))

# Combine all the individual artist dataframes into one big dataframe
df_artists = pd.concat(artist_frames, ignore_index=True)

# Merge the top tracks dataframe with the artist details dataframe
df_top_tracks_genre = df_top_tracks.merge(df_artists, left_on='artist', right_on='name', how='left')
df_top_tracks_genre_copy = df_top_tracks_genre.copy()
display(df_top_tracks_genre.head())
# Out:
#                        id           name_x                  album  \
# 0  1HkOPLwAJH3kE8UnqgxF4s      Skinny Love  For Emma, Forever Ago
# 1  5DBmXF7QO43Cuy9yqva116  Family Business    The College Dropout
# 2  4vHNeBWDQpVCmGbaccrRzi       Goodie Bag             Goodie Bag
# 3  694vvR5o19xHPhhJ5QdLN7          NO HALO                 GINGER
# 4  093CMFUwvPyFIsjBsVfBPO  El Hob El Kebir        El Hob El Kebir
#
#          artist  duration_ms  popularity  time_range        name_y  \
# 0      Bon Iver       238532          69  short_term      Bon Iver
# 1    Kanye West       278893          67  short_term    Kanye West
# 2   Still Woozy       146390          78  short_term   Still Woozy
# 3  BROCKHAMPTON       259746          59  short_term  BROCKHAMPTON
# 4  Ragheb Alama       315640          50  short_term  Ragheb Alama
#
#                                               genres
# 0  [chamber pop, eau claire indie, indie folk, me...
# 1                        [chicago rap, hip hop, rap]
# 2           [bedroom pop, oakland indie, pov: indie]
# 3                                    [boy band, rap]
# 4                   [classic arab pop, lebanese pop]

# %% [markdown]
# We now access rich track details for each track in top tracks. For each track ID from your top tracks, we can access a detailed set of attributes using the audio_features endpoint in Spotipy. These attributes, such as danceability, energy, and tempo, provide insights into the nature and mood of each track. This is identical to how we included it for our saved tracks list as well.

# %%
# Getting Audio Features for Top Tracks
track_ids = df_top_tracks_genre['id'].tolist()
audio_features_list = []

# Batching requests for efficiency
for i in range(0, len(track_ids), 50):
    batch = track_ids[i:i+50]
    audio_features = sp.audio_features(batch)
    audio_features_list.extend(audio_features)

df_audio_features = pd.DataFrame(audio_features_list)
#create a copy of the original version we can refer to just in case after data cleaning/manipulation
df_audio_features_copy = df_audio_features.copy()
display(df_audio_features.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.592   0.256    4   -14.031     0       0.0449       0.84200
# 1         0.744   0.524    1    -7.452     1       0.2100       0.13900
# 2         0.739   0.522    7   -12.304     0       0.1510       0.82100
# 3         0.643   0.573    4    -7.034     1       0.0709       0.41000
# 4         0.621   0.965    7    -3.887     0       0.0431       0.00248
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0880    0.103   76.358  audio_features
# 1          0.000000    0.3920    0.606   93.691  audio_features
# 2          0.001240    0.2330    0.619  138.263  audio_features
# 3          0.000170    0.0695    0.470  165.192  audio_features
# 4          0.000169    0.1190    0.809  144.971  audio_features
#
#                        id                                   uri  \
# 0  1HkOPLwAJH3kE8UnqgxF4s  spotify:track:1HkOPLwAJH3kE8UnqgxF4s
# 1  5DBmXF7QO43Cuy9yqva116  spotify:track:5DBmXF7QO43Cuy9yqva116
# 2  4vHNeBWDQpVCmGbaccrRzi  spotify:track:4vHNeBWDQpVCmGbaccrRzi
# 3  694vvR5o19xHPhhJ5QdLN7  spotify:track:694vvR5o19xHPhhJ5QdLN7
# 4  093CMFUwvPyFIsjBsVfBPO  spotify:track:093CMFUwvPyFIsjBsVfBPO
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1HkOPLwAJH3k...
# 1  https://api.spotify.com/v1/tracks/5DBmXF7QO43C...
# 2  https://api.spotify.com/v1/tracks/4vHNeBWDQpVC...
# 3  https://api.spotify.com/v1/tracks/694vvR5o19xH...
# 4  https://api.spotify.com/v1/tracks/093CMFUwvPyF...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1HkO...       238533
# 1  https://api.spotify.com/v1/audio-analysis/5DBm...       278893
# 2  https://api.spotify.com/v1/audio-analysis/4vHN...       146390
# 3  https://api.spotify.com/v1/audio-analysis/694v...       259747
# 4  https://api.spotify.com/v1/audio-analysis/093C...       315640
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# Artist Additional Details:
#
# For every artist ID from your top artists, we can retrieve more extensive information using the artist endpoint in Spotipy. This data provides a deeper understanding of each artist, including genres they're associated with, their popularity, and more.

# %%
# Getting Additional Details for Top Artists
artist_ids = df_top_artists['id'].tolist()
artist_details_list = []

# Batching requests for efficiency
for i in range(0, len(artist_ids), 50):
    batch = artist_ids[i:i+50]
    artist_details = sp.artists(batch)
    artist_details_list.extend(artist_details['artists'])
df_artist_details = pd.DataFrame(artist_details_list)
#create a copy of the original version we can refer to just in case after data cleaning/manipulation
df_artist_details_copy = df_artist_details.copy()
display(df_artist_details.head())
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/0...
# 1  {'spotify': 'https://open.spotify.com/artist/5...
# 2  {'spotify': 'https://open.spotify.com/artist/2...
# 3  {'spotify': 'https://open.spotify.com/artist/0...
# 4  {'spotify': 'https://open.spotify.com/artist/5...
#
#                            followers                                 genres  \
# 0    {'href': None, 'total': 274200}               [arab pop, lebanese pop]
# 1  {'href': None, 'total': 20790700}            [chicago rap, hip hop, rap]
# 2  {'href': None, 'total': 11541738}             [lgbtq+ hip hop, neo soul]
# 3   {'href': None, 'total': 1518868}  [arab pop, belly dance, lebanese pop]
# 4    {'href': None, 'total': 301593}        [arab pop, dabke, lebanese pop]
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/04N4sGkSTSx...  04N4sGkSTSxjVfbiItLvTj
# 1  https://api.spotify.com/v1/artists/5K4W6rqBFWD...  5K4W6rqBFWDnAN6FQUkS6x
# 2  https://api.spotify.com/v1/artists/2h93pZq0e7k...  2h93pZq0e7k5yf4dywlkpM
# 3  https://api.spotify.com/v1/artists/09A6IffSw0t...  09A6IffSw0t8L8sfuOCVws
# 4  https://api.spotify.com/v1/artists/5DPb3SKW8QZ...  5DPb3SKW8QZFwkRlmt7Gvo
#
#                                               images           name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Ziad Bourji
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Kanye West
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Frank Ocean
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Wael Kfoury
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Joseph Attieh
#
#    popularity    type                                    uri
# 0          43  artist  spotify:artist:04N4sGkSTSxjVfbiItLvTj
# 1          88  artist  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x
# 2          81  artist  spotify:artist:2h93pZq0e7k5yf4dywlkpM
# 3          52  artist  spotify:artist:09A6IffSw0t8L8sfuOCVws
# 4          40  artist  spotify:artist:5DPb3SKW8QZFwkRlmt7Gvo

# %% [markdown]
# We now merge our original top tracks and top artists dataframes with the additonal track details and additional artist details (relevant columns only) dataframes to provide a compehrensive summary of track and artist info in a single dataframe for each.

# %%
# Merge on track IDs
df_top_tracks_detailed = df_top_tracks_genre.merge(df_audio_features, on='id', how='left')
#keep an original of the merged top_Tracks as we will make changes to the original after this point
df_top_tracks_detailed_copy = df_top_tracks_detailed.copy()
# Extract relevant columns from artist details
df_artist_details_subset = df_artist_details[['id', 'popularity', 'followers']]

# Merge on artist IDs
df_top_artists_detailed = df_top_artists.merge(df_artist_details_subset, on='id', how='left')
#keep an original of the merged top artists as we will make changes to the original after this point
df_top_artists_detailed_copy = df_top_artists_detailed.copy()

display(df_top_tracks_detailed.head())
display(df_top_artists_detailed.head())
# Out:
#                        id           name_x                  album  \
# 0  1HkOPLwAJH3kE8UnqgxF4s      Skinny Love  For Emma, Forever Ago
# 1  1HkOPLwAJH3kE8UnqgxF4s      Skinny Love  For Emma, Forever Ago
# 2  5DBmXF7QO43Cuy9yqva116  Family Business    The College Dropout
# 3  5DBmXF7QO43Cuy9yqva116  Family Business    The College Dropout
# 4  4vHNeBWDQpVCmGbaccrRzi       Goodie Bag             Goodie Bag
#
#         artist  duration_ms_x  popularity  time_range       name_y  \
# 0     Bon Iver         238532          69  short_term     Bon Iver
# 1     Bon Iver         238532          69  short_term     Bon Iver
# 2   Kanye West         278893          67  short_term   Kanye West
# 3   Kanye West         278893          67  short_term   Kanye West
# 4  Still Woozy         146390          78  short_term  Still Woozy
#
#                                               genres  danceability  energy  \
# 0  [chamber pop, eau claire indie, indie folk, me...         0.592   0.256
# 1  [chamber pop, eau claire indie, indie folk, me...         0.592   0.256
# 2                        [chicago rap, hip hop, rap]         0.744   0.524
# 3                        [chicago rap, hip hop, rap]         0.744   0.524
# 4           [bedroom pop, oakland indie, pov: indie]         0.739   0.522
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    4   -14.031     0       0.0449         0.842          0.000002     0.088
# 1    4   -14.031     0       0.0449         0.842          0.000002     0.088
# 2    1    -7.452     1       0.2100         0.139          0.000000     0.392
# 3    1    -7.452     1       0.2100         0.139          0.000000     0.392
# 4    7   -12.304     0       0.1510         0.821          0.001240     0.233
#
#    valence    tempo            type                                   uri  \
# 0    0.103   76.358  audio_features  spotify:track:1HkOPLwAJH3kE8UnqgxF4s
# 1    0.103   76.358  audio_features  spotify:track:1HkOPLwAJH3kE8UnqgxF4s
# 2    0.606   93.691  audio_features  spotify:track:5DBmXF7QO43Cuy9yqva116
# 3    0.606   93.691  audio_features  spotify:track:5DBmXF7QO43Cuy9yqva116
# 4    0.619  138.263  audio_features  spotify:track:4vHNeBWDQpVCmGbaccrRzi
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1HkOPLwAJH3k...
# 1  https://api.spotify.com/v1/tracks/1HkOPLwAJH3k...
# 2  https://api.spotify.com/v1/tracks/5DBmXF7QO43C...
# 3  https://api.spotify.com/v1/tracks/5DBmXF7QO43C...
# 4  https://api.spotify.com/v1/tracks/4vHNeBWDQpVC...
#
#                                         analysis_url  duration_ms_y  \
# 0  https://api.spotify.com/v1/audio-analysis/1HkO...         238533
# 1  https://api.spotify.com/v1/audio-analysis/1HkO...         238533
# 2  https://api.spotify.com/v1/audio-analysis/5DBm...         278893
# 3  https://api.spotify.com/v1/audio-analysis/5DBm...         278893
# 4  https://api.spotify.com/v1/audio-analysis/4vHN...         146390
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#                        id         name                     genres  \
# 0  04N4sGkSTSxjVfbiItLvTj  Ziad Bourji     arab pop, lebanese pop
# 1  04N4sGkSTSxjVfbiItLvTj  Ziad Bourji     arab pop, lebanese pop
# 2  04N4sGkSTSxjVfbiItLvTj  Ziad Bourji     arab pop, lebanese pop
# 3  5K4W6rqBFWDnAN6FQUkS6x   Kanye West  chicago rap, hip hop, rap
# 4  5K4W6rqBFWDnAN6FQUkS6x   Kanye West  chicago rap, hip hop, rap
#
#    followers_count  popularity_x  time_range  popularity_y  \
# 0                0            43  short_term            43
# 1                0            43  short_term            43
# 2                0            43  short_term            43
# 3                0            88  short_term            88
# 4                0            88  short_term            88
#
#                            followers
# 0    {'href': None, 'total': 274200}
# 1    {'href': None, 'total': 274200}
# 2    {'href': None, 'total': 274200}
# 3  {'href': None, 'total': 20790700}
# 4  {'href': None, 'total': 20790700}

# %% [markdown]
# We now begin our data cleaning, each cell will provide an overview  (statistical distribution, null count/column, datframe size, datatypes) for each dataframe in question (saved tracks, top tracks, top artists). Utilising df.head(), df.info(), df.describe() allows us to get a good overview of our data for cleaning and any other things we should note for the visualisations performed in the next notebook file.

# %%
# Convert 'release_date' to datetime
df_saved_tracks_with_audio_features['release_date'] = pd.to_datetime(df_saved_tracks_with_audio_features['release_date'])
# Convert 'added_at' to datetime
df_saved_tracks_with_audio_features['added_at'] = pd.to_datetime(df_saved_tracks_with_audio_features['added_at'])
#convert genre to string for duplicate_drop
df_saved_tracks_with_audio_features['genres'] = df_saved_tracks_with_audio_features['genres'].astype(str)
#drop duplicate column occurring after adding genre for saved tracks
if 'name_y' in df_saved_tracks_genre:
    df_saved_tracks_with_audio_features = df_saved_tracks_with_audio_features.drop(columns='name_y')
#drop duplicate column occurring after merging audio features with saved tracks
if "duration_ms_y" in df_saved_tracks_with_audio_features:
    df_saved_tracks_with_audio_features=df_saved_tracks_with_audio_features.drop(columns='duration_ms_y')
#drop duplicate rows
df_saved_tracks_with_audio_features.drop_duplicates(inplace=True)
#reset index to maintain index order
df_saved_tracks_with_audio_features = df_saved_tracks_with_audio_features.reset_index(drop=True)
#overview of saved tracks dataframe after cleaning/dropping duplicates
display(df_saved_tracks_with_audio_features.head(10))
display(df_saved_tracks_with_audio_features.info())
display(df_saved_tracks_with_audio_features.isnull().sum())
display(df_saved_tracks_with_audio_features.describe())
# Out:
#                        id                           name_x       artist  \
# 0  2UOopL3Y405ruJyMzJcdWD                     Khserna Baad    Maya Diab
# 1  0WVTQp3SOCuMr08jh1jweV           Bring It On Home to Me    Sam Cooke
# 2  1XPj5quoeV5Gd0paSUDpvm               You Send Me - Mono    Sam Cooke
# 3  2G0GextMwZJLkNxcSZ7ZJ3  (What A) Wonderful World - Mono    Sam Cooke
# 4  1HkOPLwAJH3kE8UnqgxF4s                      Skinny Love     Bon Iver
# 5  432hUIl3ISDeytYW5XBQ5h                           Wolves   Kanye West
# 6  1w327AHTCoChRIkJUprAnV                           Mirage    Orion Sun
# 7  5DBmXF7QO43Cuy9yqva116                  Family Business   Kanye West
# 8  4vHNeBWDQpVCmGbaccrRzi                       Goodie Bag  Still Woozy
# 9  4vju55Ag7apDL2CfotuE7Q                            Sunny   Bobby Hebb
#
#                                             album release_date  duration_ms_x  \
# 0                                    Khserna Baad   2019-06-03         187561
# 1                       The Man Who Invented Soul   2000-09-26         162533
# 2                                       Sam Cooke   1958-02-01         165733
# 3                The Wonderful World Of Sam Cooke   1960-02-01         128786
# 4                           For Emma, Forever Ago   2008-05-12         238532
# 5                               The Life Of Pablo   2016-06-10         301586
# 6  A Collection of Fleeting Moments and Daydreams   2020-01-06          57495
# 7                             The College Dropout   2004-02-10         278893
# 8                                      Goodie Bag   2017-11-05         146390
# 9                                           Sunny   1966-01-01         165066
#
#                    added_at  \
# 0 2023-08-03 19:11:51+00:00
# 1 2023-08-01 16:48:21+00:00
# 2 2023-07-23 14:55:49+00:00
# 3 2023-07-20 01:18:55+00:00
# 4 2023-07-20 00:55:48+00:00
# 5 2023-07-16 12:12:03+00:00
# 6 2023-06-23 23:50:17+00:00
# 7 2023-06-16 01:15:36+00:00
# 8 2023-06-09 18:11:19+00:00
# 9 2023-05-25 01:24:16+00:00
#
#                                               genres  danceability  energy  \
# 0                       ['arab pop', 'lebanese pop']         0.689   0.605
# 1             ['classic soul', 'soul', 'vocal jazz']         0.523   0.402
# 2             ['classic soul', 'soul', 'vocal jazz']         0.572   0.365
# 3             ['classic soul', 'soul', 'vocal jazz']         0.686   0.672
# 4  ['chamber pop', 'eau claire indie', 'indie fol...         0.592   0.256
# 5                  ['chicago rap', 'hip hop', 'rap']         0.395   0.392
# 6                 ['alternative r&b', 'bedroom pop']         0.683   0.468
# 7                  ['chicago rap', 'hip hop', 'rap']         0.744   0.524
# 8     ['bedroom pop', 'oakland indie', 'pov: indie']         0.739   0.522
# 9                                  ['northern soul']         0.714   0.338
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    7    -7.917     0       0.0776         0.127          0.000000    0.0827
# 1    0    -8.233     1       0.0305         0.778          0.000000    0.4320
# 2    4    -7.583     0       0.0276         0.880          0.000000    0.1250
# 3   11    -5.523     1       0.0323         0.700          0.000000    0.1350
# 4    4   -14.031     0       0.0449         0.842          0.000002    0.0880
# 5    1    -8.034     1       0.0925         0.219          0.001730    0.1340
# 6    9   -10.058     0       0.0743         0.870          0.673000    0.1080
# 7    1    -7.452     1       0.2100         0.139          0.000000    0.3920
# 8    7   -12.304     0       0.1510         0.821          0.001240    0.2330
# 9    4   -10.994     0       0.0456         0.930          0.006440    0.3890
#
#    valence    tempo            type                                   uri  \
# 0    0.146   87.017  audio_features  spotify:track:2UOopL3Y405ruJyMzJcdWD
# 1    0.675   70.863  audio_features  spotify:track:0WVTQp3SOCuMr08jh1jweV
# 2    0.410   96.022  audio_features  spotify:track:1XPj5quoeV5Gd0paSUDpvm
# 3    0.857  128.550  audio_features  spotify:track:2G0GextMwZJLkNxcSZ7ZJ3
# 4    0.103   76.358  audio_features  spotify:track:1HkOPLwAJH3kE8UnqgxF4s
# 5    0.103  155.856  audio_features  spotify:track:432hUIl3ISDeytYW5XBQ5h
# 6    0.470  117.095  audio_features  spotify:track:1w327AHTCoChRIkJUprAnV
# 7    0.606   93.691  audio_features  spotify:track:5DBmXF7QO43Cuy9yqva116
# 8    0.619  138.263  audio_features  spotify:track:4vHNeBWDQpVCmGbaccrRzi
# 9    0.667  128.385  audio_features  spotify:track:4vju55Ag7apDL2CfotuE7Q
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2UOopL3Y405r...
# 1  https://api.spotify.com/v1/tracks/0WVTQp3SOCuM...
# 2  https://api.spotify.com/v1/tracks/1XPj5quoeV5G...
# 3  https://api.spotify.com/v1/tracks/2G0GextMwZJL...
# 4  https://api.spotify.com/v1/tracks/1HkOPLwAJH3k...
# 5  https://api.spotify.com/v1/tracks/432hUIl3ISDe...
# 6  https://api.spotify.com/v1/tracks/1w327AHTCoCh...
# 7  https://api.spotify.com/v1/tracks/5DBmXF7QO43C...
# 8  https://api.spotify.com/v1/tracks/4vHNeBWDQpVC...
# 9  https://api.spotify.com/v1/tracks/4vju55Ag7apD...
#
#                                         analysis_url  time_signature
# 0  https://api.spotify.com/v1/audio-analysis/2UOo...               4
# 1  https://api.spotify.com/v1/audio-analysis/0WVT...               4
# 2  https://api.spotify.com/v1/audio-analysis/1XPj...               4
# 3  https://api.spotify.com/v1/audio-analysis/2G0G...               4
# 4  https://api.spotify.com/v1/audio-analysis/1HkO...               4
# 5  https://api.spotify.com/v1/audio-analysis/432h...               4
# 6  https://api.spotify.com/v1/audio-analysis/1w32...               4
# 7  https://api.spotify.com/v1/audio-analysis/5DBm...               4
# 8  https://api.spotify.com/v1/audio-analysis/4vHN...               4
# 9  https://api.spotify.com/v1/audio-analysis/4vju...               4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                791 non-null    object
#  1   name_x            791 non-null    object
#  2   artist            791 non-null    object
#  3   album             791 non-null    object
#  4   release_date      791 non-null    datetime64[ns]
#  5   duration_ms_x     791 non-null    int64
#  6   added_at          791 non-null    datetime64[ns, UTC]
#  7   genres            791 non-null    object
#  8   danceability      791 non-null    float64
#  9   energy            791 non-null    float64
#  10  key               791 non-null    int64
#  11  loudness          791 non-null    float64
#  12  mode              791 non-null    int64
#  13  speechiness       791 non-null    float64
#  14  acousticness      791 non-null    float64
#  15  instrumentalness  791 non-null    float64
#  16  liveness          791 non-null    float64
#  17  valence           791 non-null    float64
#  18  tempo             791 non-null    float64
#  19  type              791 non-null    object
#  20  uri               791 non-null    object
#  21  track_href        791 non-null    object
#  22  analysis_url      791 non-null    object
#  23  time_signature    791 non-null    int64
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(9), int64(4), object(9)
# memory usage: 148.4+ KB
# None
# id                  0
# name_x              0
# artist              0
# album               0
# release_date        0
# duration_ms_x       0
# added_at            0
# genres              0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# uri                 0
# track_href          0
# analysis_url        0
# time_signature      0
# dtype: int64
#        duration_ms_x  danceability      energy         key    loudness  \
# count     791.000000    791.000000  791.000000  791.000000  791.000000
# mean   225172.455120      0.609549    0.552569    5.161820   -8.751134
# std     91691.547592      0.167871    0.202468    3.581826    4.167771
# min      9106.000000      0.000000    0.011300    0.000000  -34.673000
# 25%    174799.500000      0.498000    0.414500    2.000000  -10.712500
# 50%    216320.000000      0.622000    0.565000    5.000000   -7.915000
# 75%    270743.500000      0.735000    0.709500    8.000000   -5.936500
# max    760973.000000      0.967000    0.977000   11.000000   -0.158000
#
#              mode  speechiness  acousticness  instrumentalness    liveness  \
# count  791.000000   791.000000    791.000000        791.000000  791.000000
# mean     0.590392     0.154147      0.368665          0.074728    0.210558
# std      0.492073     0.156323      0.303945          0.207064    0.170028
# min      0.000000     0.000000      0.000068          0.000000    0.029800
# 25%      0.000000     0.040550      0.088200          0.000000    0.103000
# 50%      1.000000     0.081100      0.290000          0.000023    0.138000
# 75%      1.000000     0.233000      0.624000          0.006005    0.273500
# max      1.000000     0.948000      0.996000          0.968000    0.982000
#
#           valence       tempo  time_signature
# count  791.000000  791.000000      791.000000
# mean     0.468970  118.155296        3.876106
# std      0.235077   32.459954        0.560129
# min      0.000000    0.000000        0.000000
# 25%      0.285000   92.892000        4.000000
# 50%      0.466000  116.919000        4.000000
# 75%      0.642000  140.117500        4.000000
# max      0.972000  210.164000        5.000000

# %%
#Cleaning top tracks  dataframe

#first we take a look at top_tracks and of audio_features info
#top tracks
print('General Top Tracks Info:')
display(df_top_tracks_genre.head(10))
display(df_top_tracks_genre.info())
display(df_top_tracks_genre.isnull().sum())
display(df_top_tracks_genre.describe())
#audio features
print('Audio features Top Tracks Info:')
display(df_audio_features.head(10))
display(df_audio_features.info())
display(df_audio_features.isnull().sum())
display(df_audio_features.describe())
# now lets ensure our merged dataframe is as expected
print('Merged Top Tracks and Audio Features')
#converting genres from list to string to drop duplicate rows
df_top_tracks_detailed['genres'] = df_top_tracks_detailed['genres'].astype(str)
# Drop duplicate rows and duration
df_top_tracks_detailed.drop_duplicates(inplace=True)
#dropping duplicate columns
if 'duration_y' in df_top_tracks_detailed:
    df_top_tracks_detailed.drop('duration_y', axis=1, inplace=True)
if 'name_y' in df_top_tracks_detailed:
    df_top_tracks_detailed.drop('name_y', axis=1, inplace=True)
df_top_tracks_detailed = df_top_tracks_detailed.reset_index(drop=True)
display(df_top_tracks_detailed.head(10))
display(df_top_tracks_detailed.info())
display(df_top_tracks_detailed.isnull().sum())
display(df_top_tracks_detailed.describe())
# Out:
# General Top Tracks Info:
#                        id            name_x                  album  \
# 0  1HkOPLwAJH3kE8UnqgxF4s       Skinny Love  For Emma, Forever Ago
# 1  5DBmXF7QO43Cuy9yqva116   Family Business    The College Dropout
# 2  4vHNeBWDQpVCmGbaccrRzi        Goodie Bag             Goodie Bag
# 3  694vvR5o19xHPhhJ5QdLN7           NO HALO                 GINGER
# 4  093CMFUwvPyFIsjBsVfBPO   El Hob El Kebir        El Hob El Kebir
# 5  4vju55Ag7apDL2CfotuE7Q             Sunny                  Sunny
# 6  1T8BJvWzqm59RIuwQaTob8  Aghla El Habayeb               Yama Alo
# 7  2OG1u9eX4Zjsi7fGQB9T8t         اخدني معك              حبك علمني
# 8  2UOopL3Y405ruJyMzJcdWD      Khserna Baad           Khserna Baad
# 9  2nZKHO69mzHL9GtNWzAKpy      Habibi Wayno           Habibi Wayno
#
#             artist  duration_ms  popularity  time_range           name_y  \
# 0         Bon Iver       238532          69  short_term         Bon Iver
# 1       Kanye West       278893          67  short_term       Kanye West
# 2      Still Woozy       146390          78  short_term      Still Woozy
# 3     BROCKHAMPTON       259746          59  short_term     BROCKHAMPTON
# 4     Ragheb Alama       315640          50  short_term     Ragheb Alama
# 5       Bobby Hebb       165066          71  short_term       Bobby Hebb
# 6  Nawal Al Zoghbi       280673          44  short_term  Nawal Al Zoghbi
# 7         فضل شاكر       313939          46  short_term         فضل شاكر
# 8        Maya Diab       187561          44  short_term        Maya Diab
# 9      Ziad Bourji       286149          42  short_term      Ziad Bourji
#
#                                               genres
# 0  [chamber pop, eau claire indie, indie folk, me...
# 1                        [chicago rap, hip hop, rap]
# 2           [bedroom pop, oakland indie, pov: indie]
# 3                                    [boy band, rap]
# 4                   [classic arab pop, lebanese pop]
# 5                                    [northern soul]
# 6                    [arab pop, dabke, lebanese pop]
# 7                                                 []
# 8                           [arab pop, lebanese pop]
# 9                           [arab pop, lebanese pop]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           150 non-null    object
#  1   name_x       150 non-null    object
#  2   album        150 non-null    object
#  3   artist       150 non-null    object
#  4   duration_ms  150 non-null    int64
#  5   popularity   150 non-null    int64
#  6   time_range   150 non-null    object
#  7   name_y       148 non-null    object
#  8   genres       148 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 11.7+ KB
# None
# id             0
# name_x         0
# album          0
# artist         0
# duration_ms    0
# popularity     0
# time_range     0
# name_y         2
# genres         2
# dtype: int64
#          duration_ms  popularity
# count     150.000000   150.00000
# mean   239424.480000    54.52000
# std     66858.571266    18.76657
# min     62375.000000     0.00000
# 25%    198885.750000    43.00000
# 50%    232098.500000    54.50000
# 75%    276988.500000    70.00000
# max    427093.000000    92.00000
# Audio features Top Tracks Info:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.592   0.256    4   -14.031     0       0.0449       0.84200
# 1         0.744   0.524    1    -7.452     1       0.2100       0.13900
# 2         0.739   0.522    7   -12.304     0       0.1510       0.82100
# 3         0.643   0.573    4    -7.034     1       0.0709       0.41000
# 4         0.621   0.965    7    -3.887     0       0.0431       0.00248
# 5         0.714   0.338    4   -10.994     0       0.0456       0.93000
# 6         0.612   0.736    7    -8.630     0       0.0696       0.40200
# 7         0.607   0.623    4    -8.804     0       0.0463       0.22400
# 8         0.689   0.605    7    -7.917     0       0.0776       0.12700
# 9         0.635   0.889   10    -5.512     1       0.0859       0.20500
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.0880    0.103   76.358  audio_features
# 1          0.000000    0.3920    0.606   93.691  audio_features
# 2          0.001240    0.2330    0.619  138.263  audio_features
# 3          0.000170    0.0695    0.470  165.192  audio_features
# 4          0.000169    0.1190    0.809  144.971  audio_features
# 5          0.006440    0.3890    0.667  128.385  audio_features
# 6          0.000575    0.2680    0.688  167.972  audio_features
# 7          0.000156    0.0482    0.280   88.093  audio_features
# 8          0.000000    0.0827    0.146   87.017  audio_features
# 9          0.000004    0.0437    0.682   96.946  audio_features
#
#                        id                                   uri  \
# 0  1HkOPLwAJH3kE8UnqgxF4s  spotify:track:1HkOPLwAJH3kE8UnqgxF4s
# 1  5DBmXF7QO43Cuy9yqva116  spotify:track:5DBmXF7QO43Cuy9yqva116
# 2  4vHNeBWDQpVCmGbaccrRzi  spotify:track:4vHNeBWDQpVCmGbaccrRzi
# 3  694vvR5o19xHPhhJ5QdLN7  spotify:track:694vvR5o19xHPhhJ5QdLN7
# 4  093CMFUwvPyFIsjBsVfBPO  spotify:track:093CMFUwvPyFIsjBsVfBPO
# 5  4vju55Ag7apDL2CfotuE7Q  spotify:track:4vju55Ag7apDL2CfotuE7Q
# 6  1T8BJvWzqm59RIuwQaTob8  spotify:track:1T8BJvWzqm59RIuwQaTob8
# 7  2OG1u9eX4Zjsi7fGQB9T8t  spotify:track:2OG1u9eX4Zjsi7fGQB9T8t
# 8  2UOopL3Y405ruJyMzJcdWD  spotify:track:2UOopL3Y405ruJyMzJcdWD
# 9  2nZKHO69mzHL9GtNWzAKpy  spotify:track:2nZKHO69mzHL9GtNWzAKpy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1HkOPLwAJH3k...
# 1  https://api.spotify.com/v1/tracks/5DBmXF7QO43C...
# 2  https://api.spotify.com/v1/tracks/4vHNeBWDQpVC...
# 3  https://api.spotify.com/v1/tracks/694vvR5o19xH...
# 4  https://api.spotify.com/v1/tracks/093CMFUwvPyF...
# 5  https://api.spotify.com/v1/tracks/4vju55Ag7apD...
# 6  https://api.spotify.com/v1/tracks/1T8BJvWzqm59...
# 7  https://api.spotify.com/v1/tracks/2OG1u9eX4Zjs...
# 8  https://api.spotify.com/v1/tracks/2UOopL3Y405r...
# 9  https://api.spotify.com/v1/tracks/2nZKHO69mzHL...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1HkO...       238533
# 1  https://api.spotify.com/v1/audio-analysis/5DBm...       278893
# 2  https://api.spotify.com/v1/audio-analysis/4vHN...       146390
# 3  https://api.spotify.com/v1/audio-analysis/694v...       259747
# 4  https://api.spotify.com/v1/audio-analysis/093C...       315640
# 5  https://api.spotify.com/v1/audio-analysis/4vju...       165067
# 6  https://api.spotify.com/v1/audio-analysis/1T8B...       280674
# 7  https://api.spotify.com/v1/audio-analysis/2OG1...       313940
# 8  https://api.spotify.com/v1/audio-analysis/2UOo...       187562
# 9  https://api.spotify.com/v1/audio-analysis/2nZK...       286150
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      150 non-null    float64
#  1   energy            150 non-null    float64
#  2   key               150 non-null    int64
#  3   loudness          150 non-null    float64
#  4   mode              150 non-null    int64
#  5   speechiness       150 non-null    float64
#  6   acousticness      150 non-null    float64
#  7   instrumentalness  150 non-null    float64
#  8   liveness          150 non-null    float64
#  9   valence           150 non-null    float64
#  10  tempo             150 non-null    float64
#  11  type              150 non-null    object
#  12  id                150 non-null    object
#  13  uri               150 non-null    object
#  14  track_href        150 non-null    object
#  15  analysis_url      150 non-null    object
#  16  duration_ms       150 non-null    int64
#  17  time_signature    150 non-null    int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 21.2+ KB
# None
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64
#        danceability      energy         key    loudness        mode  \
# count    150.000000  150.000000  150.000000  150.000000  150.000000
# mean       0.604800    0.536238    5.013333   -8.520553    0.480000
# std        0.142184    0.186905    3.525529    2.912444    0.501274
# min        0.278000    0.031600    0.000000  -22.895000    0.000000
# 25%        0.526250    0.419750    2.000000   -9.939250    0.000000
# 50%        0.621000    0.561000    5.000000   -7.976500    0.000000
# 75%        0.710500    0.657500    8.000000   -6.634000    1.000000
# max        0.913000    0.965000   11.000000   -3.715000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   150.000000    150.000000        150.000000  150.000000  150.000000
# mean      0.066732      0.419996          0.027663    0.174531    0.524309
# std       0.052623      0.289847          0.113705    0.124021    0.239391
# min       0.024300      0.002390          0.000000    0.033500    0.055300
# 25%       0.033200      0.154750          0.000000    0.092600    0.328250
# 50%       0.043250      0.389000          0.000041    0.132000    0.545000
# 75%       0.084325      0.653000          0.002375    0.209750    0.692500
# max       0.382000      0.979000          0.944000    0.641000    0.970000
#
#             tempo    duration_ms  time_signature
# count  150.000000     150.000000      150.000000
# mean   122.536713  239433.520000        3.926667
# std     34.067496   66851.896543        0.261556
# min     48.718000   62375.000000        3.000000
# 25%     92.801750  198886.500000        4.000000
# 50%    120.652000  232099.000000        4.000000
# 75%    148.072750  276988.500000        4.000000
# max    201.960000  427093.000000        4.000000
# Merged Top Tracks and Audio Features
#                        id            name_x                  album  \
# 0  1HkOPLwAJH3kE8UnqgxF4s       Skinny Love  For Emma, Forever Ago
# 1  5DBmXF7QO43Cuy9yqva116   Family Business    The College Dropout
# 2  4vHNeBWDQpVCmGbaccrRzi        Goodie Bag             Goodie Bag
# 3  694vvR5o19xHPhhJ5QdLN7           NO HALO                 GINGER
# 4  093CMFUwvPyFIsjBsVfBPO   El Hob El Kebir        El Hob El Kebir
# 5  4vju55Ag7apDL2CfotuE7Q             Sunny                  Sunny
# 6  1T8BJvWzqm59RIuwQaTob8  Aghla El Habayeb               Yama Alo
# 7  2OG1u9eX4Zjsi7fGQB9T8t         اخدني معك              حبك علمني
# 8  2UOopL3Y405ruJyMzJcdWD      Khserna Baad           Khserna Baad
# 9  2nZKHO69mzHL9GtNWzAKpy      Habibi Wayno           Habibi Wayno
#
#             artist  duration_ms_x  popularity  time_range  \
# 0         Bon Iver         238532          69  short_term
# 1       Kanye West         278893          67  short_term
# 2      Still Woozy         146390          78  short_term
# 3     BROCKHAMPTON         259746          59  short_term
# 4     Ragheb Alama         315640          50  short_term
# 5       Bobby Hebb         165066          71  short_term
# 6  Nawal Al Zoghbi         280673          44  short_term
# 7         فضل شاكر         313939          46  short_term
# 8        Maya Diab         187561          44  short_term
# 9      Ziad Bourji         286149          42  short_term
#
#                                               genres  danceability  energy  \
# 0  ['chamber pop', 'eau claire indie', 'indie fol...         0.592   0.256
# 1                  ['chicago rap', 'hip hop', 'rap']         0.744   0.524
# 2     ['bedroom pop', 'oakland indie', 'pov: indie']         0.739   0.522
# 3                                ['boy band', 'rap']         0.643   0.573
# 4               ['classic arab pop', 'lebanese pop']         0.621   0.965
# 5                                  ['northern soul']         0.714   0.338
# 6              ['arab pop', 'dabke', 'lebanese pop']         0.612   0.736
# 7                                                 []         0.607   0.623
# 8                       ['arab pop', 'lebanese pop']         0.689   0.605
# 9                       ['arab pop', 'lebanese pop']         0.635   0.889
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    4   -14.031     0       0.0449       0.84200          0.000002    0.0880
# 1    1    -7.452     1       0.2100       0.13900          0.000000    0.3920
# 2    7   -12.304     0       0.1510       0.82100          0.001240    0.2330
# 3    4    -7.034     1       0.0709       0.41000          0.000170    0.0695
# 4    7    -3.887     0       0.0431       0.00248          0.000169    0.1190
# 5    4   -10.994     0       0.0456       0.93000          0.006440    0.3890
# 6    7    -8.630     0       0.0696       0.40200          0.000575    0.2680
# 7    4    -8.804     0       0.0463       0.22400          0.000156    0.0482
# 8    7    -7.917     0       0.0776       0.12700          0.000000    0.0827
# 9   10    -5.512     1       0.0859       0.20500          0.000004    0.0437
#
#    valence    tempo            type                                   uri  \
# 0    0.103   76.358  audio_features  spotify:track:1HkOPLwAJH3kE8UnqgxF4s
# 1    0.606   93.691  audio_features  spotify:track:5DBmXF7QO43Cuy9yqva116
# 2    0.619  138.263  audio_features  spotify:track:4vHNeBWDQpVCmGbaccrRzi
# 3    0.470  165.192  audio_features  spotify:track:694vvR5o19xHPhhJ5QdLN7
# 4    0.809  144.971  audio_features  spotify:track:093CMFUwvPyFIsjBsVfBPO
# 5    0.667  128.385  audio_features  spotify:track:4vju55Ag7apDL2CfotuE7Q
# 6    0.688  167.972  audio_features  spotify:track:1T8BJvWzqm59RIuwQaTob8
# 7    0.280   88.093  audio_features  spotify:track:2OG1u9eX4Zjsi7fGQB9T8t
# 8    0.146   87.017  audio_features  spotify:track:2UOopL3Y405ruJyMzJcdWD
# 9    0.682   96.946  audio_features  spotify:track:2nZKHO69mzHL9GtNWzAKpy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1HkOPLwAJH3k...
# 1  https://api.spotify.com/v1/tracks/5DBmXF7QO43C...
# 2  https://api.spotify.com/v1/tracks/4vHNeBWDQpVC...
# 3  https://api.spotify.com/v1/tracks/694vvR5o19xH...
# 4  https://api.spotify.com/v1/tracks/093CMFUwvPyF...
# 5  https://api.spotify.com/v1/tracks/4vju55Ag7apD...
# 6  https://api.spotify.com/v1/tracks/1T8BJvWzqm59...
# 7  https://api.spotify.com/v1/tracks/2OG1u9eX4Zjs...
# 8  https://api.spotify.com/v1/tracks/2UOopL3Y405r...
# 9  https://api.spotify.com/v1/tracks/2nZKHO69mzHL...
#
#                                         analysis_url  duration_ms_y  \
# 0  https://api.spotify.com/v1/audio-analysis/1HkO...         238533
# 1  https://api.spotify.com/v1/audio-analysis/5DBm...         278893
# 2  https://api.spotify.com/v1/audio-analysis/4vHN...         146390
# 3  https://api.spotify.com/v1/audio-analysis/694v...         259747
# 4  https://api.spotify.com/v1/audio-analysis/093C...         315640
# 5  https://api.spotify.com/v1/audio-analysis/4vju...         165067
# 6  https://api.spotify.com/v1/audio-analysis/1T8B...         280674
# 7  https://api.spotify.com/v1/audio-analysis/2OG1...         313940
# 8  https://api.spotify.com/v1/audio-analysis/2UOo...         187562
# 9  https://api.spotify.com/v1/audio-analysis/2nZK...         286150
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                150 non-null    object
#  1   name_x            150 non-null    object
#  2   album             150 non-null    object
#  3   artist            150 non-null    object
#  4   duration_ms_x     150 non-null    int64
#  5   popularity        150 non-null    int64
#  6   time_range        150 non-null    object
#  7   genres            150 non-null    object
#  8   danceability      150 non-null    float64
#  9   energy            150 non-null    float64
#  10  key               150 non-null    int64
#  11  loudness          150 non-null    float64
#  12  mode              150 non-null    int64
#  13  speechiness       150 non-null    float64
#  14  acousticness      150 non-null    float64
#  15  instrumentalness  150 non-null    float64
#  16  liveness          150 non-null    float64
#  17  valence           150 non-null    float64
#  18  tempo             150 non-null    float64
#  19  type              150 non-null    object
#  20  uri               150 non-null    object
#  21  track_href        150 non-null    object
#  22  analysis_url      150 non-null    object
#  23  duration_ms_y     150 non-null    int64
#  24  time_signature    150 non-null    int64
# dtypes: float64(9), int64(6), object(10)
# memory usage: 29.4+ KB
# None
# id                  0
# name_x              0
# album               0
# artist              0
# duration_ms_x       0
# popularity          0
# time_range          0
# genres              0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms_y       0
# time_signature      0
# dtype: int64
#        duration_ms_x  popularity  danceability      energy         key  \
# count     150.000000   150.00000    150.000000  150.000000  150.000000
# mean   239424.480000    54.52000      0.604800    0.536238    5.013333
# std     66858.571266    18.76657      0.142184    0.186905    3.525529
# min     62375.000000     0.00000      0.278000    0.031600    0.000000
# 25%    198885.750000    43.00000      0.526250    0.419750    2.000000
# 50%    232098.500000    54.50000      0.621000    0.561000    5.000000
# 75%    276988.500000    70.00000      0.710500    0.657500    8.000000
# max    427093.000000    92.00000      0.913000    0.965000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  150.000000  150.000000   150.000000    150.000000        150.000000
# mean    -8.520553    0.480000     0.066732      0.419996          0.027663
# std      2.912444    0.501274     0.052623      0.289847          0.113705
# min    -22.895000    0.000000     0.024300      0.002390          0.000000
# 25%     -9.939250    0.000000     0.033200      0.154750          0.000000
# 50%     -7.976500    0.000000     0.043250      0.389000          0.000041
# 75%     -6.634000    1.000000     0.084325      0.653000          0.002375
# max     -3.715000    1.000000     0.382000      0.979000          0.944000
#
#          liveness     valence       tempo  duration_ms_y  time_signature
# count  150.000000  150.000000  150.000000     150.000000      150.000000
# mean     0.174531    0.524309  122.536713  239433.520000        3.926667
# std      0.124021    0.239391   34.067496   66851.896543        0.261556
# min      0.033500    0.055300   48.718000   62375.000000        3.000000
# 25%      0.092600    0.328250   92.801750  198886.500000        4.000000
# 50%      0.132000    0.545000  120.652000  232099.000000        4.000000
# 75%      0.209750    0.692500  148.072750  276988.500000        4.000000
# max      0.641000    0.970000  201.960000  427093.000000        4.000000

# %%
#Cleaning top artists detailed dataframe

#first we take a look at top_artist and of artist_detailed info
#top artists
print('General Top Artist Info:')
display(df_top_artists.head(10))
display(df_top_artists.info())
display(df_top_artists.isnull().sum())
display(df_top_artists.describe())
#artist details
print('Artist Detail General Info:')
display(df_artist_details.head(10))
display(df_artist_details.info())
display(df_artist_details.isnull().sum())
display(df_artist_details.describe())
#merged dataframe for artists
print('Merged Artist and Artist Detail Dataframe')
#change dictionary datatype to string so as not to encounter errors when dropping row duplicates
df_top_artists_detailed['followers'] = df_top_artists_detailed['followers'].astype(str)
# Drop duplicate rows
df_top_artists_detailed.drop_duplicates(inplace=True)
#drop duplicate columns
if 'followers_count' in df_top_artists_detailed:
    df_top_artists_detailed.drop('followers_count', axis=1, inplace=True)
if 'popularity_y' in df_top_artists_detailed:  
    df_top_artists_detailed.drop('popularity_y', axis=1, inplace=True)
#reset index
df_top_artists_detailed = df_top_artists_detailed.reset_index(drop=True)
display(df_top_artists_detailed.head(10))
display(df_top_artists_detailed.info())
display(df_top_artists_detailed.isnull().sum())
display(df_top_artists_detailed.describe())
# Out:
# General Top Artist Info:
#                        id           name  \
# 0  04N4sGkSTSxjVfbiItLvTj    Ziad Bourji
# 1  5K4W6rqBFWDnAN6FQUkS6x     Kanye West
# 2  2h93pZq0e7k5yf4dywlkpM    Frank Ocean
# 3  09A6IffSw0t8L8sfuOCVws    Wael Kfoury
# 4  5DPb3SKW8QZFwkRlmt7Gvo  Joseph Attieh
# 5  3AA28KZvwAUcZuOKwyblJQ       Gorillaz
# 6  4LLpKhyESsyAXpc4laK94U     Mac Miller
# 7  6hnWRPzGGKiapVX1UCdEAC      Sam Cooke
# 8  4b5UHpUmrPycvsgu2M3ujz      Maya Diab
# 9  1Bl6wpkWCQ4KVgnASpvzzA   BROCKHAMPTON
#
#                                    genres  followers_count  popularity  \
# 0                  arab pop, lebanese pop                0          43
# 1               chicago rap, hip hop, rap                0          88
# 2                lgbtq+ hip hop, neo soul                0          81
# 3     arab pop, belly dance, lebanese pop                0          52
# 4           arab pop, dabke, lebanese pop                0          40
# 5  alternative hip hop, modern rock, rock                0          77
# 6   hip hop, pittsburgh rap, pop rap, rap                0          81
# 7          classic soul, soul, vocal jazz                0          66
# 8                  arab pop, lebanese pop                0          41
# 9                           boy band, rap                0          64
#
#    time_range
# 0  short_term
# 1  short_term
# 2  short_term
# 3  short_term
# 4  short_term
# 5  short_term
# 6  short_term
# 7  short_term
# 8  short_term
# 9  short_term
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               146 non-null    object
#  1   name             146 non-null    object
#  2   genres           146 non-null    object
#  3   followers_count  146 non-null    int64
#  4   popularity       146 non-null    int64
#  5   time_range       146 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 7.0+ KB
# None
# id                 0
# name               0
# genres             0
# followers_count    0
# popularity         0
# time_range         0
# dtype: int64
#        followers_count  popularity
# count            146.0  146.000000
# mean               0.0   60.356164
# std                0.0   19.387070
# min                0.0   20.000000
# 25%                0.0   43.000000
# 50%                0.0   61.000000
# 75%                0.0   77.000000
# max                0.0  100.000000
# Artist Detail General Info:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/0...
# 1  {'spotify': 'https://open.spotify.com/artist/5...
# 2  {'spotify': 'https://open.spotify.com/artist/2...
# 3  {'spotify': 'https://open.spotify.com/artist/0...
# 4  {'spotify': 'https://open.spotify.com/artist/5...
# 5  {'spotify': 'https://open.spotify.com/artist/3...
# 6  {'spotify': 'https://open.spotify.com/artist/4...
# 7  {'spotify': 'https://open.spotify.com/artist/6...
# 8  {'spotify': 'https://open.spotify.com/artist/4...
# 9  {'spotify': 'https://open.spotify.com/artist/1...
#
#                            followers  \
# 0    {'href': None, 'total': 274200}
# 1  {'href': None, 'total': 20790700}
# 2  {'href': None, 'total': 11541738}
# 3   {'href': None, 'total': 1518868}
# 4    {'href': None, 'total': 301593}
# 5  {'href': None, 'total': 10725672}
# 6   {'href': None, 'total': 9319926}
# 7   {'href': None, 'total': 1516294}
# 8    {'href': None, 'total': 161555}
# 9   {'href': None, 'total': 2127842}
#
#                                      genres  \
# 0                  [arab pop, lebanese pop]
# 1               [chicago rap, hip hop, rap]
# 2                [lgbtq+ hip hop, neo soul]
# 3     [arab pop, belly dance, lebanese pop]
# 4           [arab pop, dabke, lebanese pop]
# 5  [alternative hip hop, modern rock, rock]
# 6   [hip hop, pittsburgh rap, pop rap, rap]
# 7          [classic soul, soul, vocal jazz]
# 8                  [arab pop, lebanese pop]
# 9                           [boy band, rap]
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/04N4sGkSTSx...  04N4sGkSTSxjVfbiItLvTj
# 1  https://api.spotify.com/v1/artists/5K4W6rqBFWD...  5K4W6rqBFWDnAN6FQUkS6x
# 2  https://api.spotify.com/v1/artists/2h93pZq0e7k...  2h93pZq0e7k5yf4dywlkpM
# 3  https://api.spotify.com/v1/artists/09A6IffSw0t...  09A6IffSw0t8L8sfuOCVws
# 4  https://api.spotify.com/v1/artists/5DPb3SKW8QZ...  5DPb3SKW8QZFwkRlmt7Gvo
# 5  https://api.spotify.com/v1/artists/3AA28KZvwAU...  3AA28KZvwAUcZuOKwyblJQ
# 6  https://api.spotify.com/v1/artists/4LLpKhyESsy...  4LLpKhyESsyAXpc4laK94U
# 7  https://api.spotify.com/v1/artists/6hnWRPzGGKi...  6hnWRPzGGKiapVX1UCdEAC
# 8  https://api.spotify.com/v1/artists/4b5UHpUmrPy...  4b5UHpUmrPycvsgu2M3ujz
# 9  https://api.spotify.com/v1/artists/1Bl6wpkWCQ4...  1Bl6wpkWCQ4KVgnASpvzzA
#
#                                               images           name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Ziad Bourji
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Kanye West
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Frank Ocean
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...    Wael Kfoury
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Joseph Attieh
# 5  [{'height': 640, 'url': 'https://i.scdn.co/ima...       Gorillaz
# 6  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Mac Miller
# 7  [{'height': 640, 'url': 'https://i.scdn.co/ima...      Sam Cooke
# 8  [{'height': 640, 'url': 'https://i.scdn.co/ima...      Maya Diab
# 9  [{'height': 640, 'url': 'https://i.scdn.co/ima...   BROCKHAMPTON
#
#    popularity    type                                    uri
# 0          43  artist  spotify:artist:04N4sGkSTSxjVfbiItLvTj
# 1          88  artist  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x
# 2          81  artist  spotify:artist:2h93pZq0e7k5yf4dywlkpM
# 3          52  artist  spotify:artist:09A6IffSw0t8L8sfuOCVws
# 4          40  artist  spotify:artist:5DPb3SKW8QZFwkRlmt7Gvo
# 5          77  artist  spotify:artist:3AA28KZvwAUcZuOKwyblJQ
# 6          81  artist  spotify:artist:4LLpKhyESsyAXpc4laK94U
# 7          66  artist  spotify:artist:6hnWRPzGGKiapVX1UCdEAC
# 8          41  artist  spotify:artist:4b5UHpUmrPycvsgu2M3ujz
# 9          64  artist  spotify:artist:1Bl6wpkWCQ4KVgnASpvzzA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   external_urls  146 non-null    object
#  1   followers      146 non-null    object
#  2   genres         146 non-null    object
#  3   href           146 non-null    object
#  4   id             146 non-null    object
#  5   images         146 non-null    object
#  6   name           146 non-null    object
#  7   popularity     146 non-null    int64
#  8   type           146 non-null    object
#  9   uri            146 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 11.5+ KB
# None
# external_urls    0
# followers        0
# genres           0
# href             0
# id               0
# images           0
# name             0
# popularity       0
# type             0
# uri              0
# dtype: int64
#        popularity
# count  146.000000
# mean    60.356164
# std     19.387070
# min     20.000000
# 25%     43.000000
# 50%     61.000000
# 75%     77.000000
# max    100.000000
# Merged Artist and Artist Detail Dataframe
#                        id           name  \
# 0  04N4sGkSTSxjVfbiItLvTj    Ziad Bourji
# 1  5K4W6rqBFWDnAN6FQUkS6x     Kanye West
# 2  2h93pZq0e7k5yf4dywlkpM    Frank Ocean
# 3  09A6IffSw0t8L8sfuOCVws    Wael Kfoury
# 4  5DPb3SKW8QZFwkRlmt7Gvo  Joseph Attieh
# 5  3AA28KZvwAUcZuOKwyblJQ       Gorillaz
# 6  4LLpKhyESsyAXpc4laK94U     Mac Miller
# 7  6hnWRPzGGKiapVX1UCdEAC      Sam Cooke
# 8  4b5UHpUmrPycvsgu2M3ujz      Maya Diab
# 9  1Bl6wpkWCQ4KVgnASpvzzA   BROCKHAMPTON
#
#                                    genres  popularity_x  time_range  \
# 0                  arab pop, lebanese pop            43  short_term
# 1               chicago rap, hip hop, rap            88  short_term
# 2                lgbtq+ hip hop, neo soul            81  short_term
# 3     arab pop, belly dance, lebanese pop            52  short_term
# 4           arab pop, dabke, lebanese pop            40  short_term
# 5  alternative hip hop, modern rock, rock            77  short_term
# 6   hip hop, pittsburgh rap, pop rap, rap            81  short_term
# 7          classic soul, soul, vocal jazz            66  short_term
# 8                  arab pop, lebanese pop            41  short_term
# 9                           boy band, rap            64  short_term
#
#                            followers
# 0    {'href': None, 'total': 274200}
# 1  {'href': None, 'total': 20790700}
# 2  {'href': None, 'total': 11541738}
# 3   {'href': None, 'total': 1518868}
# 4    {'href': None, 'total': 301593}
# 5  {'href': None, 'total': 10725672}
# 6   {'href': None, 'total': 9319926}
# 7   {'href': None, 'total': 1516294}
# 8    {'href': None, 'total': 161555}
# 9   {'href': None, 'total': 2127842}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            146 non-null    object
#  1   name          146 non-null    object
#  2   genres        146 non-null    object
#  3   popularity_x  146 non-null    int64
#  4   time_range    146 non-null    object
#  5   followers     146 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 7.0+ KB
# None
# id              0
# name            0
# genres          0
# popularity_x    0
# time_range      0
# followers       0
# dtype: int64
#        popularity_x
# count    146.000000
# mean      60.356164
# std       19.387070
# min       20.000000
# 25%       43.000000
# 50%       61.000000
# 75%       77.000000
# max      100.000000

# %% [markdown]
# Let us now save all our clean dataframes that we intend to use for data visualisation in our data visualisation notebook (see next file)

# %%
df_saved_tracks_with_audio_features.to_csv('saved_tracks.csv', index=False)
df_top_tracks_detailed.to_csv('top_tracks.csv', index=False)
df_top_artists_detailed.to_csv('top_artists.csv',index=False)

# %% [markdown]
# The below is me having fun by extracting the features of a recently released single, produced in my home studio, by my friends in the band Koteri :)

# %%
song_name = "Something I Need"
df_song = df_saved_tracks_genre.loc[df_saved_tracks_genre['name_x'] == song_name]
song_row = df_saved_tracks_genre.loc[df_saved_tracks_genre['name_x'] == song_name]
song_id = song_row['id'].values[0] # This gets the id of the song
audio_features = sp.audio_features(song_id)[0]  # The [0] is to unpack the result from a list
audio_features=pd.DataFrame([audio_features])
display(df_song.head())
display(audio_features.head())
# Out:
#                         id            name_x  artist             album  \
# 19  5j3so8OA4ddWtvObRxy0zm  Something I Need  Koteri  Something I Need
#
#    release_date  duration_ms                  added_at genres
# 19   2023-03-21       216236 2023-03-21 16:11:21+00:00     []
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.585   0.563    9    -7.198     0       0.0414         0.706
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0           0.00342     0.132    0.626  80.003  audio_features
#
#                        id                                   uri  \
# 0  5j3so8OA4ddWtvObRxy0zm  spotify:track:5j3so8OA4ddWtvObRxy0zm
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5j3so8OA4ddW...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5j3s...       216237
#
#    time_signature
# 0               4

# %% [markdown]
# Spotipy library will typically handle refreshing the access token automatically in most instances. And since this is not a large scale applciation setting up a way to handle token refresh is not so important even though it's good practice. Considering the above points, the following cell below allows one to verify if the user's access token is still active or is expired/close to expiring, especially handy for debugging to ensure token expiry or authentication is not the issue.

# %%
import time

def is_token_expired(token_info):
    now = int(time.time())
    return token_info['expires_at'] - now < 60  # less than a minute to expire

if is_token_expired(token_info):
    print("Token has expired or is about to expire.")
else:
    print("Token is still valid.")
# Out:
# Token is still valid.
